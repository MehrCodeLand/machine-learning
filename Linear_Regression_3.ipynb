# %%
import seaborn as sns 
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('datas/Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# preprocessing Data and Polynomial Regression
X = df.drop('Sales', axis=1)
X = X.drop('Unnamed: 0' , axis = 1)

y = df['Sales']

# %%
# A B A*b AA BB

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(
    degree=2,
    include_bias=False
)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = polynomial_converter.transform(X)

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
X.shape
# Out:
# (200, 3)

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(
    poly_features,
    y,
    test_size=0.4,
    random_state=101
)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_prediction = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
y.mean()
# Out:
# 14.0225

# %%
mae = mean_absolute_error(y_test, test_prediction)

mse =mean_squared_error(y_test ,test_prediction)

r2 = r2_score(y_test, test_prediction)

r2
# Out:
# 0.9858391678651933

# %%
model.coef_
# Out:
# array([ 5.15632511e-02,  2.51650376e-02,  1.74854029e-02, -1.08888997e-04,
#         1.13923920e-03, -6.82208958e-05, -1.48386755e-04, -2.32829225e-05,
#         1.96943486e-05])

# %%
# time to save our model

# %%
from joblib import dump , load

# %%
dump(model , 'advertising_model_polybominal.joblib')
# Out:
# ['advertising_model_polybominal.joblib']

# %%
dump(polynomial_converter , 'poly_convertor.joblib')
# Out:
# ['poly_convertor.joblib']

# %%
# load data

# %%
campain = [[200 , 0 , 0 ]]

# %%
loaded_model = load('advertising_model_polybominal.joblib')
loaded_poly = load('poly_convertor.joblib')

# %%
campain_poly = loaded_poly.transform(campain)
# Out:
# C:\Users\micro\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
campain_poly
# Out:
# array([[  200.,     0.,     0., 40000.,     0.,     0.,     0.,     0.,
#             0.]])

# %%
loaded_model.predict(campain_poly)
# Out:
# array([10.88505368])
